# %% [markdown]
# # The following program demonstrates the classification of emial into spam or ham using NLTK and ML algorithms

# %%
#importing the required libraries
import numpy as np
import pandas as pd
import nltk
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
import string

# %% [markdown]
# # Reading the Data

# %%
#reading the data(CSV file)
df=pd.read_csv("spam.csv",encoding='latin1')
df.head(5)
# Out:
#    type                                               text Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df=df.drop(['Unnamed: 2','Unnamed: 3','Unnamed: 4'],axis=1)
df.head()
# Out:
#    type                                               text
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df['length']=df['text'].apply(len)
df.head()
# Out:
#    type                                               text  length
# 0   ham  Go until jurong point, crazy.. Available only ...     111
# 1   ham                      Ok lar... Joking wif u oni...      29
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...     155
# 3   ham  U dun say so early hor... U c already then say...      49
# 4   ham  Nah I don't think he goes to usf, he lives aro...      61

# %%
#printing the size of the dataset
df.shape
# Out:
# (5572, 3)

# %%
#getting feature names
df.columns
# Out:
# Index(['type', 'text', 'length'], dtype='object')

# %%
#checking the duplicates and remove them
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (5169, 3)

# %%
df.describe()
# Out:
#             length
# count  5169.000000
# mean     78.977945
# std      58.236293
# min       2.000000
# 25%      36.000000
# 50%      60.000000
# 75%     117.000000
# max     910.000000

# %%
df.length.describe()
# Out:
# count    5169.000000
# mean       78.977945
# std        58.236293
# min         2.000000
# 25%        36.000000
# 50%        60.000000
# 75%       117.000000
# max       910.000000
# Name: length, dtype: float64

# %%
df[df['length']==910]['text'].iloc[0]
# Out:
# "For me the love should start with attraction.i should feel that I need her every time around me.she should be the first thing which comes in my thoughts.I would start the day and end it with her.she should be there every time I dream.love will be then when my every breath has her name.my life should happen around her.my life will be named to her.I would cry for her.will give all my happiness and take all her sorrows.I will be ready to fight with anyone for her.I will be in love when I will be doing the craziest things for her.love will be when I don't have to proove anyone that my girl is the most beautiful lady on the whole planet.I will always be singing praises for her.love will be when I start up making chicken curry and end up makiing sambar.life will be the most beautiful then.will get every morning and thank god for the day because she is with me.I would like to say a lot..will tell later.."

# %%
df["type"].value_counts()
# Out:
# ham     4516
# spam     653
# Name: type, dtype: int64

# %%
#show the number of missing data(NAN,NaN,na) for each column
df.isnull().sum()
# Out:
# type      0
# text      0
# length    0
# dtype: int64

# %%
count_cls=pd.value_counts(df['type'],sort=True)
count_cls.plot(kind='bar', color=["blue","orange"])
plt.title('Bar Chart')
plt.show()

# %%
count_cls.plot(kind= 'pie', autopct='%1.2f%%')

plt.title('Pie Chart')
plt.ylabel('')
plt.show()

# %% [markdown]
# # Message Preprocessing

# %%
#function to tokenize each and every word
def tokenizer(text):
    tokenized=nltk.word_tokenize(text)
    tokenized=' '.join(tokenized)
    tokenized=tokenized.replace('n\'t','not')
    return tokenized

# %%
nltk.download('stopwords')
stop=stopwords.words('english')
print(stop)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kirti\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#creating a function to process punctuation and stopwords in the text data
def process_stop_punc(text):
    #remove punctuations
    #remove stopwords
    #return a list of clen text words
    nopunc=[char for char in text if char not in string.punctuation]
    nopunc=''.join(nopunc)
    
    clean_words=[word for word in nopunc.split() if word.lower() not in stopwords.words('english')] 
    #nopunc.split is use to get the tokens sepaately
    
    return clean_words

# %%
#functions to convert words into single form i.e. converting plural to singular and past ,past continuous to present
def stemming(List):
    stem_obj=nltk.stem.PorterStemmer() # portstemmer-oldest and effiency is good
    List=[stem_obj.stem(i) for i in List]
    message=' '.join(List)
    return message

# %%
#function to compile each and every operation
def process(text):
    return stemming(process_stop_punc(tokenizer(text)))

# %%
#show the tokenization
df['text'].head().apply(process)
# Out:
# 0    go jurong point crazi avail bugi n great world...
# 1                                ok lar joke wif u oni
# 2    free entri 2 wkli comp win fa cup final tkt 21...
# 3                  u dun say earli hor u c alreadi say
# 4                 nah think goe usf live around though
# Name: text, dtype: object

# %% [markdown]
# # Vectorizing the words

# %%
#convert a collection of data to matrix of tokens using tf-idf vectorizer
import sklearn
from sklearn.feature_extraction.text import TfidfVectorizer
message=TfidfVectorizer(analyzer=process).fit_transform(df['text'])

# %%
#getting the shape of message
message.shape
# Out:
# (5169, 61)

# %%
#using countvectorizer
from sklearn.feature_extraction.text import CountVectorizer
message1=CountVectorizer(analyzer=process).fit_transform(df['text'])

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv= CountVectorizer()

x=cv.fit(df['text'])
x.vocabulary_
# Out:
# {'go': 3550,
#  'until': 8030,
#  'jurong': 4350,
#  'point': 5920,
#  'crazy': 2327,
#  'available': 1303,
#  'only': 5537,
#  'in': 4087,
#  'bugis': 1751,
#  'great': 3634,
#  'world': 8489,
#  'la': 4476,
#  'buffet': 1749,
#  'cine': 2048,
#  'there': 7645,
#  'got': 3594,
#  'amore': 1069,
#  'wat': 8267,
#  'ok': 5504,
#  'lar': 4512,
#  'joking': 4318,
#  'wif': 8392,
#  'oni': 5533,
#  'free': 3358,
#  'entry': 2949,
#  'wkly': 8447,
#  'comp': 2165,
#  'to': 7756,
#  'win': 8405,
#  'fa': 3087,
#  'cup': 2386,
#  'final': 3207,
#  'tkts': 7743,
#  '21st': 411,
#  'may': 4930,
#  '2005': 402,
#  'text': 7595,
#  '87121': 784,
#  'receive': 6297,
#  'question': 6190,
#  'std': 7230,
#  'txt': 7933,
#  'rate': 6242,
#  'apply': 1156,
#  '08452810075over18': 77,
#  'dun': 2802,
#  'say': 6633,
#  'so': 7024,
#  'early': 2823,
#  'hor': 3927,
#  'already': 1042,
#  'then': 7640,
#  'nah': 5238,
#  'don': 2712,
#  'think': 7660,
#  'he': 3781,
#  'goes': 3558,
#  'usf': 8075,
#  'lives': 4665,
#  'around': 1207,
#  'here': 3831,
#  'though': 7680,
#  'freemsg': 3365,
#  'hey': 3841,
#  'darling': 2443,
#  'it': 4218,
#  'been': 1460,
#  'week': 8313,
#  'now': 5420,
#  'and': 1084,
#  'no': 5367,
#  'word': 8480,
#  'back': 1351,
#  'like': 4615,
#  'some': 7039,
#  'fun': 3419,
#  'you': 8609,
#  'up': 8032,
#  'for': 3308,
#  'still': 7253,
#  'tb': 7529,
#  'xxx': 8555,
#  'chgs': 2002,
#  'send': 6723,
#  '50': 607,
#  'rcv': 6255,
#  'even': 2998,
#  'my': 5223,
#  'brother': 1722,
#  'is': 4206,
#  'not': 5405,
#  'speak': 7112,
#  'with': 8433,
#  'me': 4939,
#  'they': 7653,
#  'treat': 7863,
#  'aids': 992,
#  'patent': 5722,
#  'as': 1224,
#  'per': 5764,
#  'your': 8615,
#  'request': 6406,
#  'melle': 4969,
#  'oru': 5593,
#  'minnaminunginte': 5036,
#  'nurungu': 5440,
#  'vettam': 8131,
#  'has': 3757,
#  'set': 6750,
#  'callertune': 1823,
#  'all': 1029,
#  'callers': 1822,
#  'press': 6041,
#  'copy': 2266,
#  'friends': 3381,
#  'winner': 8416,
#  'valued': 8100,
#  'network': 5317,
#  'customer': 2399,
#  'have': 3770,
#  'selected': 6709,
#  'receivea': 6298,
#  '900': 816,
#  'prize': 6073,
#  'reward': 6461,
#  'claim': 2054,
#  'call': 1813,
#  '09061701461': 224,
#  'code': 2120,
#  'kl341': 4439,
#  'valid': 8096,
#  '12': 322,
#  'hours': 3947,
#  'had': 3699,
#  'mobile': 5089,
#  '11': 312,
#  'months': 5129,
#  'or': 5570,
#  'more': 5133,
#  'entitled': 2946,
#  'update': 8037,
#  'the': 7627,
#  'latest': 4526,
#  'colour': 2141,
#  'mobiles': 5090,
#  'camera': 1835,
#  'co': 2109,
#  'on': 5525,
#  '08002986030': 61,
#  'gonna': 3574,
#  'be': 1438,
#  'home': 3901,
#  'soon': 7066,
#  'want': 8245,
#  'talk': 7496,
#  'about': 859,
#  'this': 7669,
#  'stuff': 7320,
#  'anymore': 1123,
#  'tonight': 7792,
#  've': 8115,
#  'cried': 2344,
#  'enough': 2936,
#  'today': 7763,
#  'six': 6928,
#  'chances': 1943,
#  'cash': 1889,
#  'from': 3397,
#  '100': 298,
#  '20': 397,
#  '000': 1,
#  'pounds': 5982,
#  'csh11': 2363,
#  '87575': 789,
#  'cost': 2278,
#  '150p': 351,
#  'day': 2458,
#  '6days': 680,
#  '16': 363,
#  'tsandcs': 7898,
#  'reply': 6399,
#  'hl': 3873,
#  'info': 4122,
#  'urgent': 8055,
#  'won': 8464,
#  'membership': 4975,
#  'our': 5606,
#  'jackpot': 4247,
#  '81010': 737,
#  'www': 8537,
#  'dbuk': 2463,
#  'net': 5311,
#  'lccltd': 4543,
#  'pobox': 5899,
#  '4403ldnw1a7rw18': 559,
#  'searching': 6678,
#  'right': 6473,
#  'words': 8481,
#  'thank': 7612,
#  'breather': 1691,
#  'promise': 6105,
#  'wont': 8471,
#  'take': 7488,
#  'help': 3817,
#  'granted': 3623,
#  'will': 8402,
#  'fulfil': 3415,
#  'wonderful': 8468,
#  'blessing': 1567,
#  'at': 1260,
#  'times': 7722,
#  'date': 2451,
#  'sunday': 7388,
#  'xxxmobilemovieclub': 8556,
#  'use': 8069,
#  'credit': 2334,
#  'click': 2077,
#  'wap': 8250,
#  'link': 4637,
#  'next': 5334,
#  'message': 4993,
#  'http': 3968,
#  'com': 2144,
#  'qjkgighjjgcbl': 6182,
#  'oh': 5499,
#  'watching': 8272,
#  'eh': 2870,
#  'remember': 6366,
#  'how': 3953,
#  'spell': 7127,
#  'his': 3864,
#  'name': 5244,
#  'yes': 8592,
#  'did': 2592,
#  'naughty': 5271,
#  'make': 4848,
#  'wet': 8350,
#  'fine': 3215,
#  'if': 4041,
#  'thatåõs': 7625,
#  'way': 8284,
#  'feel': 3158,
#  'its': 4225,
#  'gota': 3595,
#  'england': 2927,
#  'macedonia': 4810,
#  'dont': 2716,
#  'miss': 5052,
#  'goals': 3554,
#  'team': 7541,
#  'news': 5330,
#  'ur': 8051,
#  'national': 5265,
#  '87077': 783,
#  'eg': 2865,
#  'try': 7894,
#  'wales': 8225,
#  'scotland': 6657,
#  '4txt': 599,
#  'ì¼1': 8659,
#  'poboxox36504w45wq': 5911,
#  'that': 7621,
#  'seriously': 6743,
#  'going': 3563,
#  'ha': 3695,
#  'ì_': 8658,
#  'pay': 5734,
#  'first': 3232,
#  'when': 8362,
#  'da': 2416,
#  'stock': 7256,
#  'comin': 2155,
#  'aft': 962,
#  'finish': 3218,
#  'lunch': 4776,
#  'str': 7281,
#  'down': 2737,
#  'lor': 4719,
#  'ard': 1182,
#  'smth': 7007,
#  'ffffffffff': 3177,
#  'alright': 1043,
#  'can': 1839,
#  'meet': 4958,
#  'sooner': 7067,
#  'just': 4352,
#  'forced': 3310,
#  'myself': 5228,
#  'eat': 2835,
#  'slice': 6959,
#  'really': 6280,
#  'hungry': 3988,
#  'tho': 7676,
#  'sucks': 7357,
#  'mark': 4885,
#  'getting': 3511,
#  'worried': 8492,
#  'knows': 4450,
#  'sick': 6877,
#  'turn': 7917,
#  'pizza': 5854,
#  'lol': 4696,
#  'always': 1052,
#  'convincing': 2254,
#  'catch': 1899,
#  'bus': 1771,
#  'are': 1183,
#  'frying': 3403,
#  'an': 1079,
#  'egg': 2867,
#  'tea': 7535,
#  'eating': 2838,
#  'mom': 5110,
#  'left': 4566,
#  'over': 5627,
#  'dinner': 2624,
#  'do': 2675,
#  'love': 4740,
#  'amp': 1071,
#  'we': 8289,
#  're': 6259,
#  'packing': 5653,
#  'car': 1861,
#  'll': 4669,
#  'let': 4587,
#  'know': 4447,
#  'room': 6514,
#  'ahhh': 987,
#  'work': 8482,
#  'vaguely': 8092,
#  'what': 8355,
#  'does': 2687,
#  'wait': 8219,
#  'clear': 2071,
#  'were': 8339,
#  'sure': 7414,
#  'being': 1478,
#  'sarcastic': 6613,
#  'why': 8385,
#  'doesn': 2689,
#  'live': 4661,
#  'us': 8065,
#  'yeah': 8580,
#  'was': 8259,
#  'apologetic': 1143,
#  'fallen': 3112,
#  'out': 5609,
#  'she': 6795,
#  'actin': 904,
#  'spoilt': 7154,
#  'child': 2010,
#  'caught': 1903,
#  'till': 7719,
#  'but': 1778,
#  'doing': 2702,
#  'too': 7796,
#  'badly': 1356,
#  'cheers': 1986,
#  'tell': 7559,
#  'anything': 1129,
#  'fear': 3150,
#  'of': 5477,
#  'fainting': 3104,
#  'housework': 3951,
#  'quick': 6193,
#  'cuppa': 2388,
#  'thanks': 7613,
#  'subscription': 7345,
#  'ringtone': 6482,
#  'uk': 7963,
#  'charged': 1955,
#  'month': 5126,
#  'please': 5879,
#  'confirm': 2209,
#  'by': 1794,
#  'replying': 6400,
#  'yup': 8637,
#  'look': 4707,
#  'timings': 7726,
#  'msg': 5168,
#  'again': 970,
#  'xuhui': 8551,
#  'learn': 4556,
#  '2nd': 461,
#  'her': 3830,
#  'lesson': 4585,
#  '8am': 809,
#  'oops': 5548,
#  'roommate': 6516,
#  'done': 2714,
#  'see': 6695,
#  'letter': 4589,
#  'decide': 2481,
#  'hello': 3814,
#  'saturday': 6625,
#  'texting': 7603,
#  'decided': 2482,
#  'tomo': 7781,
#  'trying': 7896,
#  'invite': 4180,
#  'pls': 5887,
#  'ahead': 986,
#  'watts': 8280,
#  'wanted': 8247,
#  'weekend': 8315,
#  'abiola': 855,
#  'forget': 3316,
#  'need': 5291,
#  'crave': 2324,
#  'most': 5141,
#  'sweet': 7445,
#  'arabian': 1179,
#  'steed': 7237,
#  'mmmmmm': 5079,
#  'yummy': 8632,
#  '07732584351': 30,
#  'rodger': 6504,
#  'burns': 1768,
#  'tried': 7872,
#  'sms': 7002,
#  'nokia': 5377,
#  'camcorder': 1833,
#  '08000930705': 57,
#  'delivery': 2521,
#  'tomorrow': 7783,
#  'who': 8378,
#  'seeing': 6697,
#  'hope': 3919,
#  'man': 4858,
#  'well': 8330,
#  'endowed': 2917,
#  'am': 1054,
#  'lt': 4763,
#  'gt': 3663,
#  'inches': 4091,
#  'calls': 1828,
#  'messages': 4995,
#  'missed': 5054,
#  'didn': 2594,
#  'get': 3503,
#  'hep': 3829,
#  'immunisation': 4070,
#  'nigeria': 5344,
#  'fair': 3105,
#  'hopefully': 3922,
#  'tyler': 7946,
#  'could': 2289,
#  'maybe': 4932,
#  'ask': 1234,
#  'bit': 1544,
#  'stubborn': 7309,
#  'hospital': 3934,
#  'kept': 4396,
#  'telling': 7560,
#  'weak': 8290,
#  'sucker': 7355,
#  'hospitals': 3935,
#  'suckers': 7356,
#  'thinked': 7661,
#  'time': 7721,
#  'saw': 6632,
#  'class': 2063,
#  'gram': 3615,
#  'usually': 8081,
#  'runs': 6557,
#  'half': 3711,
#  'eighth': 2873,
#  'smarter': 6982,
#  'gets': 3507,
#  'almost': 1038,
#  'whole': 8379,
#  'second': 6682,
#  'fyi': 3435,
#  'ride': 6472,
#  'morning': 5137,
#  'crashing': 2323,
#  'place': 5856,
#  'wow': 8508,
#  'never': 5321,
#  'realized': 6278,
#  'embarassed': 2898,
#  'accomodations': 886,
#  'thought': 7681,
#  'liked': 4616,
#  'since': 6902,
#  'best': 1498,
#  'seemed': 6701,
#  'happy': 3746,
#  'cave': 1907,
#  'sorry': 7076,
#  'give': 3532,
#  'offered': 5484,
#  'embarassing': 2899,
#  'ac': 872,
#  'sptv': 7176,
#  'new': 5325,
#  'jersey': 4288,
#  'devils': 2573,
#  'detroit': 2567,
#  'red': 6320,
#  'wings': 8414,
#  'play': 5870,
#  'ice': 4022,
#  'hockey': 3886,
#  'correct': 2271,
#  'incorrect': 4102,
#  'end': 2913,
#  'mallika': 4857,
#  'sherawat': 6802,
#  'yesterday': 8594,
#  'find': 3212,
#  'url': 8061,
#  'congrats': 2215,
#  'year': 8581,
#  'special': 7114,
#  'cinema': 2049,
#  'pass': 5711,
#  'yours': 8619,
#  '09061209465': 219,
#  'suprman': 7412,
#  'matrix3': 4918,
#  'starwars3': 7218,
#  'etc': 2986,
#  'bx420': 1792,
#  'ip4': 4189,
#  '5we': 641,
#  '150pm': 353,
#  'later': 4525,
#  'meeting': 4960,
#  'where': 8366,
#  'reached': 6262,
#  'gauti': 3469,
#  'sehwag': 6706,
#  'odi': 5476,
#  'series': 6741,
#  'pick': 5826,
#  'burger': 1763,
#  'yourself': 8620,
#  'move': 5154,
#  'pain': 5660,
#  'killing': 4421,
#  'good': 3576,
#  'joke': 4314,
#  'girls': 3529,
#  'situation': 6925,
#  'seekers': 6698,
#  'part': 5700,
#  'checking': 1980,
#  'iq': 4195,
#  'roommates': 6517,
#  'took': 7797,
#  'forever': 3313,
#  'come': 2150,
#  'double': 2730,
#  'check': 1976,
#  'hair': 3706,
#  'dresser': 2760,
#  'said': 6583,
#  'wun': 8536,
#  'cut': 2403,
#  'short': 6837,
#  'nice': 5338,
#  'pleased': 5880,
#  'advise': 945,
#  'following': 3291,
#  'recent': 6301,
#  'review': 6459,
#  'mob': 5087,
#  'awarded': 1320,
#  '1500': 350,
#  'bonus': 1608,
#  '09066364589': 267,
#  'song': 7061,
#  'dedicated': 2492,
#  'which': 8372,
#  'dedicate': 2491,
#  'valuable': 8098,
#  'frnds': 3389,
#  'rply': 6533,
#  'complimentary': 2184,
#  'trip': 7873,
#  'eurodisinc': 2992,
#  'trav': 7855,
#  'aco': 900,
#  'entry41': 2950,
#  '1000': 299,
#  'dis': 2636,
#  '18': 368,
#  'morefrmmob': 5134,
#  'shracomorsglsuplt': 6862,
#  '10': 297,
#  'ls1': 4759,
#  '3aj': 518,
#  'hear': 3793,
#  'divorce': 2665,
#  'barbie': 1387,
#  'comes': 2152,
#  'ken': 4394,
#  'plane': 5862,
#  'wah': 8212,
#  'lucky': 4770,
#  'save': 6628,
#  'money': 5117,
#  'hee': 3806,
#  'finished': 3220,
#  'hi': 3846,
#  'babe': 1342,
#  'im': 4058,
#  'wanna': 8243,
#  'something': 7049,
#  'xx': 8552,
#  'performed': 5771,
#  'waiting': 8222,
#  'machan': 4812,
#  'once': 5529,
#  'thats': 7624,
#  'cool': 2259,
#  'gentleman': 3494,
#  'dignity': 2614,
#  'respect': 6426,
#  'peoples': 5763,
#  'very': 8130,
#  'much': 5186,
#  'shy': 6872,
#  'pa': 5649,
#  'operate': 5555,
#  'after': 963,
#  'same': 6598,
#  'looking': 4711,
#  'job': 4303,
#  'ta': 7473,
#  'earn': 2824,
#  'ah': 984,
#  'stop': 7266,
#  'urgnt': 8058,
#  'real': 6271,
#  'yo': 8604,
#  'tickets': 7709,
#  'one': 5531,
#  'jacket': 4246,
#  'used': 8070,
#  'multis': 5195,
#  'started': 7213,
#  'requests': 6407,
#  'came': 1834,
#  'bed': 1455,
#  'coins': 2126,
#  'factory': 3094,
#  'gotta': 3600,
#  'nitros': 5362,
#  'ela': 2878,
#  'kano': 4375,
#  'il': 4053,
#  'download': 2738,
#  'wen': 8333,
#  'stand': 7201,
#  'close': 2084,
#  'another': 1106,
#  'night': 5346,
#  'spent': 7132,
#  'late': 4522,
#  'afternoon': 965,
#  'casualty': 1897,
#  'means': 4946,
#  'haven': 3771,
#  'any': 1120,
#  'stuff42moro': 7321,
#  'includes': 4095,
#  'sheets': 6797,
#  'smile': 6990,
#  'pleasure': 5882,
#  'trouble': 7880,
#  'pours': 5984,
#  'rain': 6216,
#  'sum1': 7379,
#  'hurts': 3998,
#  'becoz': 1453,
#  'someone': 7043,
#  'loves': 4748,
#  'smiling': 6994,
#  'service': 6746,
#  'representative': 6404,
#  '0800': 53,
#  '169': 366,
#  '6031': 647,
#  'between': 1507,
#  '10am': 307,
#  '9pm': 835,
#  'guaranteed': 3666,
#  '5000': 609,
#  'havent': 3772,
#  'planning': 5866,
#  'buy': 1783,
#  'lido': 4600,
#  '530': 627,
#  'show': 6853,
#  'collected': 2135,
#  'simply': 6899,
#  'password': 5718,
#  'mix': 5070,
#  '85069': 770,
#  'verify': 8126,
#  'usher': 8076,
#  'britney': 1712,
#  'fml': 3282,
#  'telugu': 7565,
#  'movie': 5157,
#  'abt': 867,
#  'loads': 4675,
#  'loans': 4677,
#  'wk': 8443,
#  'hols': 3899,
#  'run': 6555,
#  'forgot': 3321,
#  'hairdressers': 3708,
#  'appointment': 1159,
#  'four': 3339,
#  'shower': 6855,
#  'beforehand': 1467,
#  'cause': 1904,
#  'prob': 6078,
#  'ham': 3717,
#  'nothing': 5410,
#  'else': 2892,
#  'okay': 5505,
#  'price': 6054,
#  'long': 4703,
#  'legal': 4569,
#  'them': 7636,
#  'ave': 1307,
#  'ams': 1075,
#  'gone': 3572,
#  '4the': 597,
#  'driving': 2769,
#  'test': 7589,
#  'yet': 8595,
#  'mean': 4942,
#  'guess': 3672,
#  'gave': 3470,
#  'boston': 1629,
#  'men': 4979,
#  'changed': 1945,
#  'search': 6677,
#  'location': 4680,
#  'nyc': 5451,
#  'cuz': 2410,
#  'signin': 6887,
#  'page': 5656,
#  'says': 6636,
#  'umma': 7970,
#  'life': 4603,
#  'vava': 8112,
#  'lot': 4727,
#  'dear': 2471,
#  'wishes': 8427,
#  'birthday': 1542,
#  'making': 4852,
#  'truly': 7889,
#  'memorable': 4976,
#  'aight': 994,
#  'hit': 3866,
#  'would': 8504,
#  'ip': 4188,
#  'address': 922,
#  'considering': 2227,
#  'computer': 2190,
#  'isn': 4213,
#  'minecraft': 5030,
#  'server': 6745,
#  'grumpy': 3660,
#  'old': 5517,
#  'people': 5762,
#  'better': 1504,
#  'lying': 4790,
#  'jokes': 4316,
#  'worry': 8494,
#  'busy': 1777,
#  'plural': 5891,
#  'noun': 5417,
#  'research': 6412,
#  'cos': 2276,
#  'things': 7659,
#  'scared': 6642,
#  'mah': 4835,
#  'loud': 4735,
#  'gent': 3492,
#  'contact': 2232,
#  'last': 4519,
#  'weekends': 8316,
#  'draw': 2752,
#  'shows': 6861,
#  '09064012160': 243,
#  'k52': 4358,
#  '12hrs': 333,
#  '150ppm': 355,
#  'wa': 8207,
#  'openin': 5552,
#  'sentence': 6734,
#  'formal': 3325,
#  'anyway': 1132,
#  'juz': 4357,
#  'tt': 7904,
#  'eatin': 2837,
#  'puttin': 6171,
#  'weight': 8321,
#  'haha': 3702,
#  'anythin': 1128,
#  'happened': 3738,
#  'entered': 2939,
#  'cabin': 1801,
#  'boss': 1628,
#  'felt': 3167,
#  'askd': 1235,
#  'invited': 4181,
#  'apartment': 1137,
#  'went': 8336,
#  'specially': 7118,
#  'holiday': 3896,
#  'flights': 3258,
#  'inc': 4089,
#  'operator': 5556,
#  '0871277810910p': 129,
#  'min': 5023,
#  'goodo': 3585,
#  'must': 5214,
#  'friday': 3376,
#  'potato': 5976,
#  'ratio': 6245,
#  'tortilla': 7814,
#  'needed': 5293,
#  'hmm': 3878,
#  'uncle': 7979,
#  'informed': 4125,
#  'paying': 5739,
#  'school': 6648,
#  'directly': 2630,
#  'food': 3298,
#  'private': 6070,
#  '2004': 401,
#  'account': 889,
#  'statement': 7221,
#  '07742676969': 32,
#  '786': 709,
#  'unredeemed': 8023,
#  'points': 5921,
#  '08719180248': 175,
#  'identifier': 4034,
#  '45239': 570,
#  'expires': 3065,
#  '2000': 399,
#  'caller': 1821,
#  '03': 15,
#  'landline': 4499,
#  '09064019788': 249,
#  'box42wr29c': 1655,
#  'apples': 1154,
#  'pairs': 5664,
#  'malarky': 4854,
#  'todays': 7764,
#  'voda': 8176,
#  'numbers': 5437,
#  'ending': 2915,
#  '7548': 701,
#  '350': 506,
#  'award': 1319,
#  'match': 4906,
#  '08712300220': 111,
#  'quoting': 6204,
#  '4041': 543,
#  'standard': 7202,
#  'rates': 6243,
#  'app': 1147,
#  'sao': 6607,
#  'mu': 5184,
#  'ìï': 8661,
#  'predict': 6016,
#  'buying': 1786,
#  'yetunde': 8597,
#  'hasn': 3759,
#  'sent': 6733,
#  'bother': 1632,
#  'sending': 6725,
#  'involve': 4185,
#  'shouldn': 6848,
#  'imposed': 4077,
#  'apologise': 1144,
#  'girl': 3526,
#  'del': 2511,
#  'bak': 1364,
#  'sum': 7378,
#  'lucyxx': 4773,
#  'tmorrow': 7749,
#  'accomodate': 885,
#  'answer': 1109,
#  'sunshine': 7395,
#  'quiz': 6200,
#  'top': 7805,
#  'sony': 7063,
#  'dvd': 2812,
#  'player': 5872,
#  'country': 2296,
#  'algarve': 1022,
#  'ansr': 1108,
#  '82277': 744,
#  'sp': 7099,
#  'tyrone': 7950,
#  'laid': 4491,
#  'dogging': 2696,
#  'locations': 4681,
#  'direct': 2629,
#  'join': 4311,
#  'largest': 4516,
#  'bt': 1738,
#  'txting': 7939,
#  'gravel': 3628,
#  '69888': 675,
#  'nt': 5427,
#  'ec2a': 2840,
#  '31p': 498,
#  'haf': 3701,
#  'msn': 5175,
#  'yijue': 8601,
#  'hotmail': 3942,
#  'him': 3857,
#  'rooms': 6518,
#  'befor': 1465,
#  'activities': 910,
#  'msgs': 5174,
#  'chat': 1966,
#  'svc': 7430,
#  'hardcore': 3748,
#  'services': 6747,
#  '69988': 679,
#  'age': 973,
#  'yr': 8627,
#  'lazy': 4542,
#  'type': 7947,
#  'lect': 4563,
#  'pouch': 5979,
#  'sir': 6914,
#  'mail': 4840,
#  'swt': 7459,
#  'nver': 5445,
#  'tired': 7729,
#  'little': 4660,
#  'lovable': 4739,
#  'persons': 5789,
#  'coz': 2309,
#  'somtimes': 7058,
#  'those': 7677,
#  'occupy': 5469,
#  'biggest': 1524,
#  'their': 7633,
#  'hearts': 3799,
#  'gud': 3668,
#  'ni8': 5336,
#  'open': 5549,
#  'ya': 8565,
#  'dot': 2729,
#  'whats': 8357,
#  'staff': 7193,
#  'taking': 7493,
#  'replied': 6397,
#  'randy': 6236,
#  'sexy': 6763,
#  'female': 3168,
#  'local': 4679,
#  'luv': 4781,
#  'netcollex': 5312,
#  'ltd': 4764,
#  '08700621170150p': 81,
#  'ummma': 7972,
#  'begin': 1471,
#  'qatar': 6177,
#  'pray': 6011,
#  'hard': 3747,
#  'deleted': 2515,
#  'sindu': 6904,
#  'birla': 1538,
#  'soft': 7029,
#  'wine': 8412,
#  'flowing': 3273,
#  'nevering': 5322,
#  'thk': 7670,
#  'plaza': 5877,
#  'typical': 7949,
#  'everywhere': 3016,
#  'dirt': 2633,
#  'floor': 3267,
#  'windows': 8409,
#  'shirt': 6816,
#  'sometimes': 7051,
#  'mouth': 5153,
#  'dream': 2755,
#  'without': 8437,
#  'chores': 2037,
#  'joy': 4329,
#  'lots': 4729,
#  'tv': 7922,
#  'exist': 3050,
#  ...}

# %% [markdown]
# # Splitting data into training tesing set

# %%
#splitting the data into 80:20 train test ratio for dataset vectorized using tf-idfvectorizer
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(message,df['type'],test_size=0.2,random_state=0)

# %%
print(X_test.shape)
print("\n")
print(y_test.shape)
# Out:
# (1034, 61)
#
#
# (1034,)

# %%
print(X_test)
# Out:
#   (0, 7)	0.36305794470957053
#   (0, 18)	0.14422677770922931
#   (0, 9)	0.1646937170041491
#   (0, 34)	0.14144518797329989
#   (0, 6)	0.3396968579661826
#   (0, 1)	0.3203534096999737
#   (0, 35)	0.09719075631146003
#   (0, 29)	0.068006924430211
#   (0, 16)	0.1025141878836897
#   (0, 14)	0.14718910697763082
#   (0, 33)	0.0853503142051478
#   (0, 15)	0.056394149739173574
#   (0, 11)	0.23203429316704538
#   (0, 30)	0.2384219233189333
#   (0, 26)	0.08266343166259318
#   (0, 24)	0.18917001288700894
#   (0, 31)	0.0755481664360632
#   (0, 0)	0.520867369594567
#   (0, 25)	0.2982025067942331
#   (0, 17)	0.07929847166825754
#   (1, 18)	0.140497234239295
#   (1, 5)	0.10608354408226665
#   (1, 34)	0.5511502932352941
#   (1, 35)	0.12623668246419428
#   (1, 29)	0.1324966825623528
#   :	:
#   (1032, 33)	0.09747226492017233
#   (1032, 15)	0.1932107299609586
#   (1032, 12)	0.22006142812078988
#   (1032, 22)	0.22480605342339754
#   (1032, 11)	0.3312364503981385
#   (1032, 13)	0.17071475729799312
#   (1032, 30)	0.2722839990566598
#   (1032, 19)	0.2117280963203821
#   (1032, 24)	0.21603704430138856
#   (1032, 28)	0.21823185777550308
#   (1032, 0)	0.47587519938463513
#   (1032, 25)	0.34055497056803885
#   (1032, 17)	0.18112180863528654
#   (1033, 7)	0.4794601013454027
#   (1033, 23)	0.19646182280661842
#   (1033, 16)	0.27076373690912836
#   (1033, 14)	0.1943802777952923
#   (1033, 12)	0.25447464764419553
#   (1033, 13)	0.19741114143468108
#   (1033, 30)	0.15743189370075253
#   (1033, 19)	0.16322543260642525
#   (1033, 24)	0.16654728695878337
#   (1033, 0)	0.41271944402114813
#   (1033, 25)	0.4725731731117151
#   (1033, 17)	0.20944564809351796

# %%
print(y_test)
# Out:
# 1851    ham
# 2375    ham
# 2743    ham
# 3324    ham
# 3995    ham
#        ...
# 2237    ham
# 4368    ham
# 3046    ham
# 4263    ham
# 2674    ham
# Name: type, Length: 1034, dtype: object

# %%
#splitting the data into 80:20 train test ratio for dataset vectorized using countvectorizer
from sklearn.model_selection import train_test_split
X_train1,X_test1,y_train1,y_test1=train_test_split(message1,df['type'],test_size=0.2,random_state=0)

# %%
print(X_test1)
# Out:
#   (0, 17)	1
#   (0, 25)	5
#   (0, 0)	10
#   (0, 31)	1
#   (0, 24)	3
#   (0, 26)	1
#   (0, 30)	4
#   (0, 11)	4
#   (0, 15)	1
#   (0, 33)	1
#   (0, 14)	2
#   (0, 16)	1
#   (0, 29)	1
#   (0, 35)	1
#   (0, 1)	2
#   (0, 6)	2
#   (0, 34)	1
#   (0, 9)	1
#   (0, 18)	2
#   (0, 7)	2
#   (1, 17)	1
#   (1, 25)	3
#   (1, 0)	16
#   (1, 31)	6
#   (1, 28)	6
#   :	:
#   (1032, 24)	3
#   (1032, 19)	3
#   (1032, 30)	4
#   (1032, 13)	2
#   (1032, 11)	5
#   (1032, 22)	3
#   (1032, 12)	2
#   (1032, 15)	3
#   (1032, 33)	1
#   (1032, 14)	1
#   (1032, 16)	1
#   (1032, 21)	1
#   (1032, 29)	4
#   (1033, 17)	1
#   (1033, 25)	3
#   (1033, 0)	3
#   (1033, 24)	1
#   (1033, 19)	1
#   (1033, 30)	1
#   (1033, 13)	1
#   (1033, 12)	1
#   (1033, 14)	1
#   (1033, 16)	1
#   (1033, 23)	1
#   (1033, 7)	1

# %%
print(y_test1)
# Out:
# 1851    ham
# 2375    ham
# 2743    ham
# 3324    ham
# 3995    ham
#        ...
# 2237    ham
# 4368    ham
# 3046    ham
# 4263    ham
# 2674    ham
# Name: type, Length: 1034, dtype: object

# %% [markdown]
# # Feeding Data and classification report of Naive Bayes classifier

# %%
#creating and training the naive bayes classifier for for dataset vectorized using tf-idfvectorizer
from sklearn.naive_bayes import MultinomialNB
classifier=MultinomialNB().fit(X_train,y_train)

# %%
print(classifier.predict(X_train))

print()
print(y_train.values)
# Out:
# ['ham' 'ham' 'ham' ... 'ham' 'ham' 'ham']
#
# ['ham' 'ham' 'ham' ... 'ham' 'ham' 'ham']

# %%
#evaluate the model and training dataset
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
pred=classifier.predict(X_train)
print(classification_report(y_train,pred))
print()
print('confusion Matrix:\n',confusion_matrix(y_train,pred))
print()
print(' training accuracy score:\n',accuracy_score(y_train,pred))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.97      0.99      0.98      3631
#         spam       0.95      0.76      0.84       504
#
#     accuracy                           0.97      4135
#    macro avg       0.96      0.88      0.91      4135
# weighted avg       0.96      0.97      0.96      4135
#
#
# confusion Matrix:
#  [[3611   20]
#  [ 123  381]]
#
#  training accuracy score:
#  0.9654171704957678

# %%
#printing the predictions
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
pred=classifier.predict(X_test)
print(classification_report(y_test,pred))
print()
print('confusion Matrix:\n',confusion_matrix(y_test,pred))
print()
print('testing accuracy score:\n',accuracy_score(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.96      1.00      0.98       885
#         spam       0.99      0.73      0.84       149
#
#     accuracy                           0.96      1034
#    macro avg       0.97      0.87      0.91      1034
# weighted avg       0.96      0.96      0.96      1034
#
#
# confusion Matrix:
#  [[884   1]
#  [ 40 109]]
#
# testing accuracy score:
#  0.960348162475822

# %%
#creating and training the naive bayes classifier for for dataset vectorized using countvectorizer
from sklearn.naive_bayes import MultinomialNB
classifier1=MultinomialNB().fit(X_train1,y_train1)

# %%
#evaluate the model and training dataset
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
pred1=classifier1.predict(X_train1)
print(classification_report(y_train1,pred1))
print()
print('confusion Matrix:\n',confusion_matrix(y_train1,pred1))
print()
print(' training accuracy score:\n',accuracy_score(y_train1,pred1))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.98      0.98      0.98      3631
#         spam       0.88      0.86      0.87       504
#
#     accuracy                           0.97      4135
#    macro avg       0.93      0.92      0.92      4135
# weighted avg       0.97      0.97      0.97      4135
#
#
# confusion Matrix:
#  [[3570   61]
#  [  73  431]]
#
#  training accuracy score:
#  0.9675937122128174

# %%
#prediction from the model
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
pred1_test=classifier1.predict(X_test1)
print(classification_report(y_test1,pred1_test))
print()
print('confusion Matrix:\n',confusion_matrix(y_test1,pred1_test))
print()
print('testing accuracy score:\n',accuracy_score(y_test1,pred1_test))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.97      0.98      0.98       885
#         spam       0.90      0.82      0.86       149
#
#     accuracy                           0.96      1034
#    macro avg       0.93      0.90      0.92      1034
# weighted avg       0.96      0.96      0.96      1034
#
#
# confusion Matrix:
#  [[871  14]
#  [ 27 122]]
#
# testing accuracy score:
#  0.960348162475822

# %% [markdown]
# # Using support-vector-machine Algorithm

# %%
#prediction using LinearSVC and GridsearchCV and tokens obtained fron TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.model_selection import GridSearchCV
param_grid={'C':[0.1,1,10,100]}
grid=GridSearchCV(LinearSVC(),param_grid,refit=True)
grid.fit(X_train,y_train)
# Out:
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# GridSearchCV(estimator=LinearSVC(), param_grid={'C': [0.1, 1, 10, 100]})

# %%
#finding best C for best parameter
print(grid.best_params_)
# Out:
# {'C': 10}

# %%
#finding best accuracy
print(grid.best_score_)
# Out:
# 0.9779927448609431

# %%
#prediction of test data
pred2=grid.predict(X_test)

# %%
#evaluate the model and training dataset
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
print(classification_report(y_test,pred2))
print()
print('confusion Matrix:\n',confusion_matrix(y_test,pred2))
print()
print('accuracy score:\n',accuracy_score(y_test,pred2))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.97      1.00      0.99       885
#         spam       0.98      0.85      0.91       149
#
#     accuracy                           0.98      1034
#    macro avg       0.98      0.92      0.95      1034
# weighted avg       0.98      0.98      0.98      1034
#
#
# confusion Matrix:
#  [[883   2]
#  [ 23 126]]
#
# accuracy score:
#  0.9758220502901354

# %%
#prediction using LinearSVC and GridsearchCV and tokens obtained fron CountVectorizer
from sklearn.svm import LinearSVC
from sklearn.model_selection import GridSearchCV
param_grid={'C':[0.1,1,10,100]}
grid=GridSearchCV(LinearSVC(),param_grid,refit=True)
grid.fit(X_train1,y_train1)
# Out:
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# GridSearchCV(estimator=LinearSVC(), param_grid={'C': [0.1, 1, 10, 100]})

# %%
#finding best C for best parameter
print(grid.best_params_)
# Out:
# {'C': 1}

# %%
#finding best accuracy
print(grid.best_score_)
# Out:
# 0.9794437726723094

# %%
#training teh dataset
grid.fit(X_train1,y_train1)
# Out:
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\kirti\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# GridSearchCV(estimator=LinearSVC(), param_grid={'C': [0.1, 1, 10, 100]})

# %%
#prediction of test data
pred3=grid.predict(X_test1)

# %%
#evaluate the model and training dataset
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
print(classification_report(y_test1,pred3))
print()
print('confusion Matrix:\n',confusion_matrix(y_test1,pred3))
print()
print('accuracy score:\n',accuracy_score(y_test1,pred3))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.98      1.00      0.99       885
#         spam       0.98      0.86      0.92       149
#
#     accuracy                           0.98      1034
#    macro avg       0.98      0.93      0.95      1034
# weighted avg       0.98      0.98      0.98      1034
#
#
# confusion Matrix:
#  [[883   2]
#  [ 21 128]]
#
# accuracy score:
#  0.9777562862669246
